# %% [markdown]
# # Spectral Clustering
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **KNN graph** and other necessary algorithms for **spectral clustering**
# - play with the **threshold** of spectral clustering
# - apply spectral clustering on toy data and **real world data**, and compare it with k-means
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked to.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math
from cluster_plot import cluster_plot

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Experiment Spectral Clustering on synthesis data

# %%
cluster_data = sio.loadmat('cluster_data.mat')
X = cluster_data['X']

# %%
# Uncomment following two line and choose proper parameters
k_in_knn_graph = 10
threshold = 0.05
# begin answer
# end answer

# implement knn_graph in knn_graph.py
from knn_graph import knn_graph

W = knn_graph(X, k_in_knn_graph, threshold)

# implement spectral in spectral
from spectral import spectral

idx = spectral(W, 2)
cluster_plot(X, idx)

# %%
from kmeans import kmeans

idx = kmeans(X, 2)
cluster_plot(X, idx)

# %% [markdown]
# ## Let's try Spectral Clustering on real-world data!

# %%
TDT2_data = sio.loadmat('TDT2_data.mat')
fea = TDT2_data['fea']
gnd = TDT2_data['gnd'].reshape(-1)

# %%
from constructW import constructW
from bestMap import bestMap
from MutualInfo import MutualInfo
from spectral import spectral

# YOUR CODE HERE
# begin answer
iters = 1

W = constructW(fea,NeighborMode='KNN')
k = np.unique(gnd).size
N = fea.shape[0]
P = fea.shape[1]

acc_spetral = 0
nmi_spetral = 0
acc_kmeans = 0
nmi_kmeans = 0

for i in range(iters):
    idx = spectral(W, k)
    spec_bestmap = bestMap(gnd, idx)
    acc_spetral += np.sum(gnd == spec_bestmap)*1.0/N
    nmi_spetral += MutualInfo(gnd,spec_bestmap)
    
    idx = kmeans(fea, k)
    kmeans_bestmap = bestMap(gnd, idx)
    acc_kmeans += np.sum(gnd == kmeans_bestmap)*1.0/N
    nmi_kmeans += MutualInfo(gnd,kmeans_bestmap)

acc_spectral /= iters
nmi_spectral /= iters
acc_kmeans /= iters
nmi_kmeans /= iters

print ("accuracy of spectral clustering:", acc_spectral)
print ("normalized mutual information of spectral cluserting: ", nmi_spectral)
print ("accuracy of kmeans:",acc_kmeans)
print ("normalized mutual information of kmeans:", nmi_kmeans)
    
# end answer
# Out:
# /Users/caijiayi/Documents/junior/data mining/dm2019summer/hw4/spectral_clustering/kmeans.py:14: ComplexWarning: Casting complex values to real discards the imaginary part
#   x = x.astype(float)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-9f16c5c86c61> in <module>
#      19
#      20 for i in range(iters):
# ---> 21     idx = spectral(W, k)
#      22     spec_bestmap = bestMap(gnd, idx)
#      23     acc_spetral += np.sum(gnd == spec_bestmap)*1.0/N
#
# ~/Documents/junior/data mining/dm2019summer/hw4/spectral_clustering/spectral.py in spectral(W, k)
#      25
#      26     vecs = vecs[:,np.argsort(vals)]
# ---> 27     idx = kmeans(vecs[:,1:k],k)
#      28
#      29     return idx
#
# ~/Documents/junior/data mining/dm2019summer/hw4/spectral_clustering/kmeans.py in kmeans(x, k)
#      31         ctrs = np.zeros(ctrs.shape)
#      32         for i in range(k):
# ---> 33             print (x[idx == i])
#      34             ctrs[i] = np.average(x[idx == i], axis=0)
#      35         iter_ctrs.append(ctrs)
#
# /usr/local/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __getitem__(self, index)
#     188
#     189         try:
# --> 190             out = N.ndarray.__getitem__(self, index)
#     191         finally:
#     192             self._getitem = False
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 4 but corresponding boolean dimension is 1
