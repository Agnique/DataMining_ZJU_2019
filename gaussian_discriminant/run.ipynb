# %% [markdown]
# # Gaussian Discriminant Analysis and MLE
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the calculation of **gaussian posterior probability** of GDA
# - find appropriate tuples of parameters for variout kinds of **decision boundary**

# %%
# some basic imports
import numpy as np
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import math
from plot_ex1 import plot_ex1, figure

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Decision boundaries are plotted in the figure variable. You may need to refer to it after every plot

# %%
# mu: 2x1 matrix, e.g. np.array([[0,0]]).T
# Sigma: 2x2 matrix e.g. nnp.array([[1, 0], [0, 1]]).T
# phi: a number e.g 0.5

# change the value for specific decision boundary

mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer

mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1,0],[0,1]]).T
mu1 = np.array([[0,0]]).T
Sigma1 = np.array([[1,0],[0,1]])
phi = 0.5

# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
figure
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9a8da9871597> in <module>()
#       8 # end answer
#       9
# ---> 10 plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
#      11 figure
#
# /Users/caijiayi/Documents/junior/data mining/hw1/dm2019summer_hw1/gaussian_discriminant/plot_ex1.py in plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, fig_title, pos)
#      13
#      14     # generate data
# ---> 15     X0 = np.random.multivariate_normal(mu0.flatten(), Sigma0, 10.0).T
#      16     X1 = np.random.multivariate_normal(mu1.flatten(), Sigma1, round(phi * N)).T
#      17
#
# AttributeError: 'int' object has no attribute 'flatten'

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Parabalic', 3)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Hyperbola', 4)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
xmu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Two parallel lines.', 5)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0


# begin answer
# end answer


plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'No boundary', 8)
figure
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
figure.savefig("hw1_gaussian_discriminant.png")
