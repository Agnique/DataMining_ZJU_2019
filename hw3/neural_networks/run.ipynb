# %% [markdown]
# # Neural Networks
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **forward** and **backward** operations for different layers in neural networks
# - implement a simple neural networks for classification
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
digit_data = sio.loadmat('digit_data.mat')
X = digit_data['X']
y = digit_data['y']
_, num_cases = X.shape
train_num_cases = num_cases * 4 // 5
X = X.reshape((400, num_cases))
X = X.transpose()
# X has the shape of (number of samples, number of pixels)
train_data = X[:train_num_cases,:]
train_label = y[:, :train_num_cases]
test_data = X[train_num_cases:, :]
test_label = y[:, train_num_cases:]
weights = {}
weights['fully1_weight'] = np.random.randn(400, 25) / 400
weights['fully1_bias'] = np.random.rand(25, 1) 
weights['fully2_weight'] = np.random.randn(25, 10) / 25
weights['fully2_bias'] = np.random.rand(10, 1)

# %% [markdown]
# ## Training

# %%
# training setting
weight_inc = {}
for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
    weight_inc[name] = np.zeros(weights[name].shape)
batch_size = 100
max_epoch = 10
momW = 0.9
wc = 0.0005
learning_rate = 0.1

# Training iterations
from get_new_weight_inc import get_new_weight_inc
from feedforward_backprop import feedforward_backprop

for epoch in range(max_epoch):
    for i in range(int(math.ceil(train_num_cases/batch_size))):
        data = train_data[i * batch_size:min((i + 1) * batch_size, train_num_cases), :]
        label = train_label[:, i * batch_size:min((i + 1) * batch_size, train_num_cases)]
        # The feedforward and backpropgation processes
        loss, accuracy, gradients = feedforward_backprop(data, label, weights)
        print('{:3}.{:2} loss:{:.3}, accuracy:{}'.format(epoch + 1, i + 1, loss, accuracy))
        # Updating weights
        for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
            weight_inc[name] = get_new_weight_inc(weight_inc[name], weights[name], momW, wc, learning_rate, gradients[name + '_grad'])
            weights[name] += weight_inc[name]
# Out:
#   1. 1 loss:0.0553, accuracy:0.99
#   1. 2 loss:0.0886, accuracy:0.98
#   1. 3 loss:0.0807, accuracy:0.98
#   1. 4 loss:0.0992, accuracy:0.97
#   1. 5 loss:0.166, accuracy:0.96
#   1. 6 loss:0.0486, accuracy:1.0
#   1. 7 loss:0.113, accuracy:0.97
#   1. 8 loss:0.0482, accuracy:1.0
#   1. 9 loss:0.0692, accuracy:0.97
#   1.10 loss:0.144, accuracy:0.95
#   1.11 loss:0.0866, accuracy:0.99
#   1.12 loss:0.168, accuracy:0.97
#   1.13 loss:0.156, accuracy:0.97
#   1.14 loss:0.152, accuracy:0.97
#   1.15 loss:0.0365, accuracy:1.0
#   1.16 loss:0.108, accuracy:0.97
#   1.17 loss:0.0891, accuracy:0.98
#   1.18 loss:0.187, accuracy:0.94
#   1.19 loss:0.159, accuracy:0.95
#   1.20 loss:0.109, accuracy:0.95
#   1.21 loss:0.114, accuracy:0.96
#   1.22 loss:0.125, accuracy:0.96
#   1.23 loss:0.129, accuracy:0.98
#   1.24 loss:0.101, accuracy:0.98
#   1.25 loss:0.0825, accuracy:0.97
#   1.26 loss:0.109, accuracy:0.96
#   1.27 loss:0.151, accuracy:0.96
#   1.28 loss:0.0926, accuracy:0.98
#   1.29 loss:0.142, accuracy:0.97
#   1.30 loss:0.0817, accuracy:0.98
#   1.31 loss:0.123, accuracy:0.94
#   1.32 loss:0.0805, accuracy:0.99
#   1.33 loss:0.189, accuracy:0.96
#   1.34 loss:0.142, accuracy:0.95
#   1.35 loss:0.188, accuracy:0.97
#   1.36 loss:0.136, accuracy:0.95
#   1.37 loss:0.132, accuracy:0.97
#   1.38 loss:0.0997, accuracy:0.98
#   1.39 loss:0.158, accuracy:0.95
#   1.40 loss:0.152, accuracy:0.96
#   2. 1 loss:0.0501, accuracy:1.0
#   2. 2 loss:0.0734, accuracy:0.99
#   2. 3 loss:0.0736, accuracy:0.97
#   2. 4 loss:0.0822, accuracy:0.99
#   2. 5 loss:0.151, accuracy:0.96
#   2. 6 loss:0.0536, accuracy:1.0
#   2. 7 loss:0.109, accuracy:0.98
#   2. 8 loss:0.0577, accuracy:0.99
#   2. 9 loss:0.0605, accuracy:0.98
#   2.10 loss:0.123, accuracy:0.96
#   2.11 loss:0.0725, accuracy:0.99
#   2.12 loss:0.143, accuracy:0.97
#   2.13 loss:0.158, accuracy:0.95
#   2.14 loss:0.16, accuracy:0.97
#   2.15 loss:0.0397, accuracy:1.0
#   2.16 loss:0.0947, accuracy:0.98
#   2.17 loss:0.0816, accuracy:0.98
#   2.18 loss:0.173, accuracy:0.94
#   2.19 loss:0.158, accuracy:0.96
#   2.20 loss:0.0993, accuracy:0.96
#   2.21 loss:0.107, accuracy:0.95
#   2.22 loss:0.0951, accuracy:0.99
#   2.23 loss:0.119, accuracy:0.97
#   2.24 loss:0.0846, accuracy:0.98
#   2.25 loss:0.0717, accuracy:0.98
#   2.26 loss:0.0973, accuracy:0.98
#   2.27 loss:0.137, accuracy:0.97
#   2.28 loss:0.0811, accuracy:0.98
#   2.29 loss:0.123, accuracy:0.97
#   2.30 loss:0.0723, accuracy:0.98
#   2.31 loss:0.113, accuracy:0.94
#   2.32 loss:0.0738, accuracy:0.98
#   2.33 loss:0.156, accuracy:0.97
#   2.34 loss:0.133, accuracy:0.96
#   2.35 loss:0.183, accuracy:0.97
#   2.36 loss:0.109, accuracy:0.96
#   2.37 loss:0.107, accuracy:0.97
#   2.38 loss:0.08, accuracy:0.99
#   2.39 loss:0.139, accuracy:0.95
#   2.40 loss:0.124, accuracy:0.96
#   3. 1 loss:0.0487, accuracy:1.0
#   3. 2 loss:0.0727, accuracy:0.99
#   3. 3 loss:0.0608, accuracy:0.99
#   3. 4 loss:0.0734, accuracy:0.99
#   3. 5 loss:0.144, accuracy:0.96
#   3. 6 loss:0.0528, accuracy:1.0
#   3. 7 loss:0.102, accuracy:0.98
#   3. 8 loss:0.0558, accuracy:0.99
#   3. 9 loss:0.0623, accuracy:0.98
#   3.10 loss:0.113, accuracy:0.97
#   3.11 loss:0.073, accuracy:0.99
#   3.12 loss:0.129, accuracy:0.97
#   3.13 loss:0.14, accuracy:0.97
#   3.14 loss:0.146, accuracy:0.96
#   3.15 loss:0.0385, accuracy:1.0
#   3.16 loss:0.0908, accuracy:0.98
#   3.17 loss:0.0642, accuracy:0.98
#   3.18 loss:0.162, accuracy:0.94
#   3.19 loss:0.149, accuracy:0.96
#   3.20 loss:0.0872, accuracy:0.96
#   3.21 loss:0.106, accuracy:0.95
#   3.22 loss:0.104, accuracy:0.95
#   3.23 loss:0.107, accuracy:0.97
#   3.24 loss:0.0744, accuracy:0.98
#   3.25 loss:0.0621, accuracy:0.99
#   3.26 loss:0.0919, accuracy:0.97
#   3.27 loss:0.125, accuracy:0.98
#   3.28 loss:0.0789, accuracy:0.97
#   3.29 loss:0.107, accuracy:0.97
#   3.30 loss:0.0601, accuracy:1.0
#   3.31 loss:0.096, accuracy:0.95
#   3.32 loss:0.0679, accuracy:0.99
#   3.33 loss:0.141, accuracy:0.98
#   3.34 loss:0.127, accuracy:0.97
#   3.35 loss:0.177, accuracy:0.96
#   3.36 loss:0.093, accuracy:0.98
#   3.37 loss:0.0886, accuracy:0.97
#   3.38 loss:0.0749, accuracy:0.99
#   3.39 loss:0.122, accuracy:0.95
#   3.40 loss:0.104, accuracy:0.96
#   4. 1 loss:0.0489, accuracy:0.99
#   4. 2 loss:0.0819, accuracy:0.97
#   4. 3 loss:0.0513, accuracy:0.99
#   4. 4 loss:0.0667, accuracy:0.98
#   4. 5 loss:0.128, accuracy:0.96
#   4. 6 loss:0.0453, accuracy:1.0
#   4. 7 loss:0.0955, accuracy:0.97
#   4. 8 loss:0.0541, accuracy:0.99
#   4. 9 loss:0.061, accuracy:0.98
#   4.10 loss:0.111, accuracy:0.96
#   4.11 loss:0.071, accuracy:0.98
#   4.12 loss:0.114, accuracy:0.97
#   4.13 loss:0.125, accuracy:0.97
#   4.14 loss:0.143, accuracy:0.96
#   4.15 loss:0.0416, accuracy:1.0
#   4.16 loss:0.0938, accuracy:0.98
#   4.17 loss:0.0556, accuracy:1.0
#   4.18 loss:0.156, accuracy:0.95
#   4.19 loss:0.142, accuracy:0.96
#   4.20 loss:0.0774, accuracy:0.98
#   4.21 loss:0.103, accuracy:0.97
#   4.22 loss:0.103, accuracy:0.95
#   4.23 loss:0.0982, accuracy:0.98
#   4.24 loss:0.0671, accuracy:0.99
#   4.25 loss:0.0526, accuracy:0.99
#   4.26 loss:0.0785, accuracy:0.99
#   4.27 loss:0.108, accuracy:0.98
#   4.28 loss:0.075, accuracy:0.97
#   4.29 loss:0.104, accuracy:0.97
#   4.30 loss:0.0567, accuracy:1.0
#   4.31 loss:0.0897, accuracy:0.96
#   4.32 loss:0.0681, accuracy:0.99
#   4.33 loss:0.12, accuracy:0.98
#   4.34 loss:0.113, accuracy:0.97
#   4.35 loss:0.163, accuracy:0.97
#   4.36 loss:0.0871, accuracy:0.99
#   4.37 loss:0.0789, accuracy:0.98
#   4.38 loss:0.0737, accuracy:0.98
#   4.39 loss:0.103, accuracy:0.96
#   4.40 loss:0.101, accuracy:0.97
#   5. 1 loss:0.0455, accuracy:1.0
#   5. 2 loss:0.0814, accuracy:0.98
#   5. 3 loss:0.0452, accuracy:1.0
#   5. 4 loss:0.0642, accuracy:0.98
#   5. 5 loss:0.124, accuracy:0.96
#   5. 6 loss:0.0404, accuracy:1.0
#   5. 7 loss:0.0953, accuracy:0.97
#   5. 8 loss:0.0514, accuracy:1.0
#   5. 9 loss:0.0622, accuracy:0.98
#   5.10 loss:0.126, accuracy:0.96
#   5.11 loss:0.0827, accuracy:0.97
#   5.12 loss:0.106, accuracy:0.97
#   5.13 loss:0.114, accuracy:0.98
#   5.14 loss:0.132, accuracy:0.96
#   5.15 loss:0.0421, accuracy:1.0
#   5.16 loss:0.0965, accuracy:0.98
#   5.17 loss:0.0646, accuracy:0.99
#   5.18 loss:0.156, accuracy:0.93
#   5.19 loss:0.137, accuracy:0.96
#   5.20 loss:0.0756, accuracy:0.98
#   5.21 loss:0.0999, accuracy:0.98
#   5.22 loss:0.109, accuracy:0.96
#   5.23 loss:0.0976, accuracy:0.98
#   5.24 loss:0.0663, accuracy:0.98
#   5.25 loss:0.0535, accuracy:0.99
#   5.26 loss:0.0694, accuracy:0.99
#   5.27 loss:0.103, accuracy:0.98
#   5.28 loss:0.0695, accuracy:0.97
#   5.29 loss:0.0982, accuracy:0.97
#   5.30 loss:0.0583, accuracy:1.0
#   5.31 loss:0.0934, accuracy:0.96
#   5.32 loss:0.0757, accuracy:0.99
#   5.33 loss:0.108, accuracy:0.98
#   5.34 loss:0.104, accuracy:0.97
#   5.35 loss:0.153, accuracy:0.99
#   5.36 loss:0.0767, accuracy:0.99
#   5.37 loss:0.0761, accuracy:0.99
#   5.38 loss:0.0699, accuracy:0.98
#   5.39 loss:0.088, accuracy:0.97
#   5.40 loss:0.101, accuracy:0.96
#   6. 1 loss:0.041, accuracy:1.0
#   6. 2 loss:0.0797, accuracy:0.98
#   6. 3 loss:0.0405, accuracy:1.0
#   6. 4 loss:0.0627, accuracy:0.98
#   6. 5 loss:0.111, accuracy:0.96
#   6. 6 loss:0.033, accuracy:1.0
#   6. 7 loss:0.0842, accuracy:0.97
#   6. 8 loss:0.0423, accuracy:1.0
#   6. 9 loss:0.056, accuracy:0.99
#   6.10 loss:0.128, accuracy:0.96
#   6.11 loss:0.0787, accuracy:0.97
#   6.12 loss:0.102, accuracy:0.97
#   6.13 loss:0.113, accuracy:0.96
#   6.14 loss:0.125, accuracy:0.96
#   6.15 loss:0.0342, accuracy:1.0
#   6.16 loss:0.0933, accuracy:0.98
#   6.17 loss:0.0688, accuracy:0.98
#   6.18 loss:0.151, accuracy:0.94
#   6.19 loss:0.141, accuracy:0.96
#   6.20 loss:0.0704, accuracy:0.99
#   6.21 loss:0.0948, accuracy:0.97
#   6.22 loss:0.0987, accuracy:0.96
#   6.23 loss:0.0915, accuracy:0.98
#   6.24 loss:0.0566, accuracy:1.0
#   6.25 loss:0.0471, accuracy:1.0
#   6.26 loss:0.0603, accuracy:0.99
#   6.27 loss:0.0979, accuracy:0.98
#   6.28 loss:0.0632, accuracy:0.99
#   6.29 loss:0.0873, accuracy:0.98
#   6.30 loss:0.052, accuracy:1.0
#   6.31 loss:0.089, accuracy:0.96
#   6.32 loss:0.0799, accuracy:0.98
#   6.33 loss:0.0959, accuracy:0.98
#   6.34 loss:0.094, accuracy:0.97
#   6.35 loss:0.148, accuracy:0.99
#   6.36 loss:0.0733, accuracy:0.99
#   6.37 loss:0.0694, accuracy:0.99
#   6.38 loss:0.0686, accuracy:0.98
#   6.39 loss:0.0812, accuracy:0.97
#   6.40 loss:0.1, accuracy:0.96
#   7. 1 loss:0.0403, accuracy:1.0
#   7. 2 loss:0.0737, accuracy:0.98
#   7. 3 loss:0.0403, accuracy:1.0
#   7. 4 loss:0.059, accuracy:0.98
#   7. 5 loss:0.12, accuracy:0.95
#   7. 6 loss:0.0372, accuracy:1.0
#   7. 7 loss:0.0798, accuracy:0.97
#   7. 8 loss:0.0408, accuracy:1.0
#   7. 9 loss:0.0514, accuracy:0.99
#   7.10 loss:0.121, accuracy:0.97
#   7.11 loss:0.0773, accuracy:0.96
#   7.12 loss:0.104, accuracy:0.97
#   7.13 loss:0.115, accuracy:0.96
#   7.14 loss:0.121, accuracy:0.96
#   7.15 loss:0.029, accuracy:1.0
#   7.16 loss:0.0716, accuracy:0.98
#   7.17 loss:0.0604, accuracy:0.99
#   7.18 loss:0.146, accuracy:0.94
#   7.19 loss:0.145, accuracy:0.96
#   7.20 loss:0.0724, accuracy:0.99
#   7.21 loss:0.0921, accuracy:0.97
#   7.22 loss:0.1, accuracy:0.97
#   7.23 loss:0.0909, accuracy:0.98
#   7.24 loss:0.0504, accuracy:0.99
#   7.25 loss:0.0419, accuracy:1.0
#   7.26 loss:0.0577, accuracy:0.99
#   7.27 loss:0.102, accuracy:0.97
#   7.28 loss:0.0549, accuracy:1.0
#   7.29 loss:0.0754, accuracy:0.98
#   7.30 loss:0.044, accuracy:1.0
#   7.31 loss:0.088, accuracy:0.96
#   7.32 loss:0.0765, accuracy:0.99
#   7.33 loss:0.0833, accuracy:0.98
#   7.34 loss:0.0824, accuracy:0.98
#   7.35 loss:0.131, accuracy:0.99
#   7.36 loss:0.0646, accuracy:0.99
#   7.37 loss:0.0647, accuracy:0.99
#   7.38 loss:0.0632, accuracy:0.99
#   7.39 loss:0.0808, accuracy:0.97
#   7.40 loss:0.0897, accuracy:0.97
#   8. 1 loss:0.0349, accuracy:1.0
#   8. 2 loss:0.0618, accuracy:0.99
#   8. 3 loss:0.037, accuracy:1.0
#   8. 4 loss:0.0562, accuracy:0.99
#   8. 5 loss:0.11, accuracy:0.95
#   8. 6 loss:0.0349, accuracy:1.0
#   8. 7 loss:0.0707, accuracy:0.98
#   8. 8 loss:0.0362, accuracy:1.0
#   8. 9 loss:0.0478, accuracy:0.99
#   8.10 loss:0.109, accuracy:0.96
#   8.11 loss:0.0695, accuracy:0.99
#   8.12 loss:0.0928, accuracy:0.97
#   8.13 loss:0.117, accuracy:0.97
#   8.14 loss:0.107, accuracy:0.96
#   8.15 loss:0.0271, accuracy:1.0
#   8.16 loss:0.0654, accuracy:0.98
#   8.17 loss:0.0582, accuracy:0.99
#   8.18 loss:0.134, accuracy:0.95
#   8.19 loss:0.125, accuracy:0.97
#   8.20 loss:0.0672, accuracy:0.99
#   8.21 loss:0.0807, accuracy:0.98
#   8.22 loss:0.102, accuracy:0.96
#   8.23 loss:0.0973, accuracy:0.97
#   8.24 loss:0.044, accuracy:0.99
#   8.25 loss:0.0372, accuracy:1.0
#   8.26 loss:0.0565, accuracy:0.99
#   8.27 loss:0.094, accuracy:0.99
#   8.28 loss:0.0513, accuracy:1.0
#   8.29 loss:0.0766, accuracy:0.98
#   8.30 loss:0.0441, accuracy:1.0
#   8.31 loss:0.0869, accuracy:0.97
#   8.32 loss:0.0662, accuracy:0.99
#   8.33 loss:0.0766, accuracy:0.98
#   8.34 loss:0.0782, accuracy:0.98
#   8.35 loss:0.131, accuracy:0.98
#   8.36 loss:0.06, accuracy:0.99
#   8.37 loss:0.0623, accuracy:1.0
#   8.38 loss:0.0571, accuracy:1.0
#   8.39 loss:0.0878, accuracy:0.97
#   8.40 loss:0.0876, accuracy:0.98
#   9. 1 loss:0.0345, accuracy:1.0
#   9. 2 loss:0.0509, accuracy:0.99
#   9. 3 loss:0.0378, accuracy:1.0
#   9. 4 loss:0.0542, accuracy:0.99
#   9. 5 loss:0.106, accuracy:0.96
#   9. 6 loss:0.0331, accuracy:1.0
#   9. 7 loss:0.0675, accuracy:0.98
#   9. 8 loss:0.0338, accuracy:1.0
#   9. 9 loss:0.0448, accuracy:1.0
#   9.10 loss:0.0974, accuracy:0.95
#   9.11 loss:0.0642, accuracy:0.98
#   9.12 loss:0.084, accuracy:0.97
#   9.13 loss:0.107, accuracy:0.97
#   9.14 loss:0.0881, accuracy:0.98
#   9.15 loss:0.0233, accuracy:1.0
#   9.16 loss:0.0573, accuracy:0.98
#   9.17 loss:0.066, accuracy:0.99
#   9.18 loss:0.128, accuracy:0.95
#   9.19 loss:0.101, accuracy:0.98
#   9.20 loss:0.0555, accuracy:1.0
#   9.21 loss:0.0699, accuracy:0.98
#   9.22 loss:0.0972, accuracy:0.96
#   9.23 loss:0.102, accuracy:0.96
#   9.24 loss:0.0424, accuracy:0.99
#   9.25 loss:0.0374, accuracy:1.0
#   9.26 loss:0.0649, accuracy:0.98
#   9.27 loss:0.0801, accuracy:0.98
#   9.28 loss:0.0486, accuracy:1.0
#   9.29 loss:0.0828, accuracy:0.98
#   9.30 loss:0.0475, accuracy:0.99
#   9.31 loss:0.089, accuracy:0.96
#   9.32 loss:0.0521, accuracy:1.0
#   9.33 loss:0.0712, accuracy:0.99
#   9.34 loss:0.0772, accuracy:0.97
#   9.35 loss:0.131, accuracy:0.98
#   9.36 loss:0.0662, accuracy:0.99
#   9.37 loss:0.0676, accuracy:0.98
#   9.38 loss:0.0482, accuracy:1.0
#   9.39 loss:0.0876, accuracy:0.98
#   9.40 loss:0.0741, accuracy:0.99
#  10. 1 loss:0.0314, accuracy:1.0
#  10. 2 loss:0.0459, accuracy:1.0
#  10. 3 loss:0.0429, accuracy:1.0
#  10. 4 loss:0.0514, accuracy:0.99
#  10. 5 loss:0.12, accuracy:0.97
#  10. 6 loss:0.0305, accuracy:1.0
#  10. 7 loss:0.0631, accuracy:0.98
#  10. 8 loss:0.0313, accuracy:1.0
#  10. 9 loss:0.0454, accuracy:1.0
#  10.10 loss:0.0871, accuracy:0.96
#  10.11 loss:0.0519, accuracy:1.0
#  10.12 loss:0.0799, accuracy:0.98
#  10.13 loss:0.109, accuracy:0.98
#  10.14 loss:0.079, accuracy:0.98
#  10.15 loss:0.0207, accuracy:1.0
#  10.16 loss:0.0572, accuracy:0.97
#  10.17 loss:0.0744, accuracy:0.97
#  10.18 loss:0.134, accuracy:0.95
#  10.19 loss:0.0873, accuracy:0.97
#  10.20 loss:0.0454, accuracy:1.0
#  10.21 loss:0.0559, accuracy:0.98
#  10.22 loss:0.0816, accuracy:0.96
#  10.23 loss:0.101, accuracy:0.96
#  10.24 loss:0.0451, accuracy:0.99
#  10.25 loss:0.0412, accuracy:1.0
#  10.26 loss:0.0723, accuracy:0.98
#  10.27 loss:0.0774, accuracy:0.99
#  10.28 loss:0.0496, accuracy:0.99
#  10.29 loss:0.0885, accuracy:0.98
#  10.30 loss:0.0442, accuracy:1.0
#  10.31 loss:0.0853, accuracy:0.97
#  10.32 loss:0.0477, accuracy:0.99
#  10.33 loss:0.0613, accuracy:0.99
#  10.34 loss:0.0715, accuracy:0.98
#  10.35 loss:0.131, accuracy:0.98
#  10.36 loss:0.0671, accuracy:0.99
#  10.37 loss:0.0683, accuracy:0.99
#  10.38 loss:0.0487, accuracy:0.99
#  10.39 loss:0.103, accuracy:0.97
#  10.40 loss:0.0715, accuracy:0.99

# %% [markdown]
# ## Testing

# %%
# TODO
loss, accuracy, _ = feedforward_backprop(test_data, test_label, weights)
print('loss:{:.3}, accuracy:{}'.format(loss, accuracy))
